# %%
#!pip install omnivoice

# %% [markdown]
# # Imports

# %%
from omnivoice import OmniVoice
import soundfile as sf
import torch
# Out:
# W0413 22:01:09.483000 23740 site-packages\torch\distributed\elastic\multiprocessing\redirects.py:29] NOTE: Redirects are currently not supported in Windows or MacOs.
# c:\Users\Caio\AppData\Local\Programs\Python\Python311\Lib\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %% [markdown]
# # Load TTS Model

# %%
# Load the model
model = OmniVoice.from_pretrained(
    "D:\\inteligencia-anti-artificial\VTuberProject\\TTS\\Model\\OmniVoice",
    device_map="cuda:0",
    dtype=torch.float16
)
# Out:
# Loading weights:   0%|          | 0/313 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/527 [00:00<?, ?it/s]

# %% [markdown]
# # Generate Audio

# %%
# Generate audio
audio = model.generate(
    text="Hello, this is a test of zero-shot voice cloning.",
    ref_text="Transcription of the reference audio.",
) # audio is a list of `np.ndarray` with shape (T,) at 24 kHz.

sf.write("out.wav", audio[0], 24000)
